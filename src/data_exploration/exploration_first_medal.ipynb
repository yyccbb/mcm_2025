# %%
import pandas as pd
import numpy as np

# %%
athletes = pd.read_csv('../data/summerOly_athletes.csv')
athletes.shape[0]
# Out:
# 252565

# %%
df_before_2024 = athletes[athletes['Year'] < 2024]

# %%
df_before_2024
# Out:
#                          Name Sex            Team  NOC  Year         City  \
# 0                   A Dijiang   M           China  CHN  1992    Barcelona
# 1                    A Lamusi   M           China  CHN  2012       London
# 2                 Gunnar Aaby   M         Denmark  DEN  1920    Antwerpen
# 3                 Edgar Aabye   M  Denmark/Sweden  DEN  1900        Paris
# 4       Cornelia (-strannood)   F     Netherlands  NED  1932  Los Angeles
# ...                       ...  ..             ...  ...   ...          ...
# 237668      Klaudia Zwolinska   F          Poland  POL  2020        Tokyo
# 237669           Yulia Zykova   F          Russia  ROC  2020        Tokyo
# 237670      Ekaterina Zyuzina   F          Russia  ROC  2020        Tokyo
# 237671        Sylwia Zyzanska   F          Poland  POL  2020        Tokyo
# 237672        Sylwia Zyzanska   F          Poland  POL  2020        Tokyo
#
#                Sport                                     Event     Medal
# ...

# %%
nocs_no_medals = df_before_2024.groupby('NOC').filter(lambda group: (group['Medal'] == "No medal").all())

# %%
nocs_no_medals
# Out:
#                      Name Sex                              Team  NOC  Year  \
# 98         M'Bairo Abakar   M                              Chad  CHA  1992
# 141     Carlos Balladares   M                         Nicaragua  NCA  2004
# 142        Carlos Abaunza   M                         Nicaragua  NCA  1976
# 153            Gana Kimet   M                              Chad  CHA  1972
# 298        Moustafa Naser   M                             Libya  LBA  1996
# ...                   ...  ..                               ...  ...   ...
# 237379        Robyn Young   F                          Eswatini  SWZ  2020
# 237421       Naomie Yumba   F  Democratic Republic of the Congo  COD  2020
# 237468      Yasmin Zammit   F                             Malta  MLT  2020
# 237486         Ivan Zarco   M                          Honduras  HON  2020
# 237519    Jean-luc Zephir   M                       Saint Lucia  LCA  2020
#
# ...

# %%
len(nocs_no_medals['Team'].unique())
# Out:
# 94

# %%
nocs_no_medals_after_2024 = athletes.groupby('NOC').filter(lambda group: (group['Medal'] == "No medal").all())

# %%
nocs_no_medals_after_2024
# Out:
#                        Name Sex               Team  NOC  Year       City  \
# 98           M'Bairo Abakar   M               Chad  CHA  1992  Barcelona
# 141       Carlos Balladares   M          Nicaragua  NCA  2004     Athina
# 142          Carlos Abaunza   M          Nicaragua  NCA  1976   Montreal
# 153              Gana Kimet   M               Chad  CHA  1972     Munich
# 298          Moustafa Naser   M              Libya  LBA  1996    Atlanta
# ...                     ...  ..                ...  ...   ...        ...
# 252523             Pyae Han   M            Myanmar  MYA  2024      Paris
# 252536      Isabella Millar   F    Solomon Islands  SOL  2024      Paris
# 252537       Davonte Howell   M     Cayman Islands  CAY  2024      Paris
# 252555  Steven Insixiengmay   M            Lao PDR  LAO  2024      Paris
# 252560           Sefora Ada   F  Equatorial Guinea  GEQ  2024      Paris
#
#             Sport                         Event     Medal
# ...

# %%
nocs_no_medals_after_2024['Team'].unique()
# Out:
# array(['Chad', 'Nicaragua', 'Libya', 'Palestine', 'Comoros', 'Brunei',
#        'Maldives', 'North Yemen', 'Congo (Brazzaville)', 'Benin',
#        'Somalia', 'Mali', 'Angola', 'Bangladesh', 'El Salvador',
#        'Honduras', 'Seychelles', 'Mauritania', 'Saint Kitts and Nevis',
#        'Saint Vincent and the Grenadines', 'Liberia', 'Nepal', 'Palau',
#        'American Samoa', 'Samoa', 'Rwanda', 'Malta', 'Guinea', 'Belize',
#        'South Yemen', 'Sierra Leone', 'Papua New Guinea', 'Yemen', 'Oman',
#        'Vanuatu', 'British Virgin Islands', 'Central African Republic',
#        'Madagascar', 'Malaya', 'Bosnia and Herzegovina', 'Guam',
#        'Cayman Islands', 'Guinea Bissau', 'Timor Leste',
#        'Congo (Kinshasa)', 'Laos', 'Refugee Olympic Athletes', 'GyoshuII',
#        'Solomon Islands', 'Crete', 'Equatorial Guinea', 'Bolivia', 'Saar',
#        'Antigua and Barbuda', 'Andorra', 'Federated States of Micronesia',
# ...

# %%
first_medals_2024 = np.setdiff1d(nocs_no_medals['Team'].unique(), nocs_no_medals_after_2024['Team'].unique())

# %%
no_medals_emerging_2024 = np.setdiff1d(nocs_no_medals_after_2024['Team'].unique(), nocs_no_medals['Team'].unique())

# %%
len(nocs_no_medals_after_2024['Team'].unique())
# Out:
# 101

# %%
filtered_ds = athletes[athletes['Team'].isin(no_medals_emerging_2024)]
filtered_ds
# Out:
#                         Name Sex                  Team  NOC  Year   City  \
# 237892       Naquille Harris   M    St Kitts and Nevis  SKN  2024  Paris
# 237899         Freddy Mayala   M                 Congo  CGO  2024  Paris
# 237903       Vanessa Bobimbo   F                 Congo  CGO  2024  Paris
# 237904         Natacha Ngoye   F                 Congo  CGO  2024  Paris
# 238009        Aphenie Greene   F  StVincent&Grenadines  VIN  2024  Paris
# 238010          Alex Joachim   M  StVincent&Grenadines  VIN  2024  Paris
# 238097  Zahria Allers-liburd   F    St Kitts and Nevis  SKN  2024  Paris
# 238226     Herminia Teixeira   F   Sao Tome & Principe  STP  2024  Paris
# 238263           de Roldeney   M   Sao Tome & Principe  STP  2024  Paris
# 238264         Gorete Semedo   F   Sao Tome & Principe  STP  2024  Paris
# 238281      Jolanio Guterres   M           Timor-Leste  TLS  2024  Paris
# 238282        Imelda Ximenes   F           Timor-Leste  TLS  2024  Paris
# ...

# %%
emerging_2024 = np.setdiff1d(athletes['Team'].unique(), df_before_2024['Team'].unique())
emerging_2024
# Out:
# array(['AIN', 'Bosnia & Herzegovina', 'Brunei Darussalam', 'Cabo Verde',
#        'Centr Afric Re', 'Congo', 'Czechia', "Côte d'Ivoire", 'DPR Korea',
#        'DR Congo', 'EOR', 'IR Iran', 'Korea', 'Lao PDR', 'Micronesia',
#        'Republic of Moldova', 'Sao Tome & Principe', 'St Kitts and Nevis',
#        'StVincent&Grenadines', 'Timor-Leste', 'Türkiye', 'UA Emirates',
#        'Virgin Islands, B', 'Virgin Islands, US'], dtype=object)

# %%
# Past participation records for countries that got their first medals in 2024
NOCs_first_medal_2024 = athletes[athletes['Team'].isin(first_medals_2024)]
NOCs_first_medal_2024
# Out:
#                           Name Sex        Team  NOC  Year            City  \
# 1751    Francilla (-schofield)   F    Dominica  DMA  2000          Sydney
# 1752               Steven Agar   M    Dominica  DMA  1996         Atlanta
# 6294             Henry Andrade   M  Cape Verde  CPV  1996         Atlanta
# 6297            Jordin Andrade   M  Cape Verde  CPV  2016  Rio de Janeiro
# 6302            Maria Teixeira   F  Cape Verde  CPV  2016  Rio de Janeiro
# ...                        ...  ..         ...  ...   ...             ...
# 243916             Thea Lafond   F    Dominica  DMA  2024           Paris
# 244847            Dennick Luke   M    Dominica  DMA  2024           Paris
# 244860       Jasmine Schofield   F    Dominica  DMA  2024           Paris
# 244875           Adam Lawrence   M    Dominica  DMA  2024           Paris
# 252390          Chermen Valiev   M     Albania  ALB  2024           Paris
#
#             Sport                                 Event     Medal
# ...

# %%
for noc in first_medals_2024:
    participating_years = athletes[athletes['Team'] == noc]['Year'].unique()
    print(f"{noc} first participated in {participating_years.min()} and got their first medal in 2024")
# Out:
# Albania first participated in 1972 and got their first medal in 2024
# Cape Verde first participated in 1996 and got their first medal in 2024
# Dominica first participated in 1996 and got their first medal in 2024
# Refugee Olympic Team first participated in 2020 and got their first medal in 2024
# Saint Lucia first participated in 1996 and got their first medal in 2024
